# %% [markdown]
# # **Function**
#
# First, we have a simple tutorial to let you become familiar with Colab and recall the function.
#
# Object: we will explore how changing the parameter impacts the function. This simple exercise demonstrates how different parameters lead to different functions, showcasing the core concept of machine learning.
#
# Lets start this exercise by computing the following function: $y = wx^2$. Here, $y$ is the output, $x$ is the input feature, and $w$ is the weight/parameter we want to explore.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define the function y = wx^2
def quadratic_function(x, w):
  return w*x**2

# %%
# Create x values
x = np.linspace(-2, 2, 50)

# %%
# Define the values of w
w_values = [1, 2, 4, 8, -1, -2, -4, -8]

# %%
# Plot the function for each value of w
for w in w_values:
    y = quadratic_function(x, w)
    plt.plot(x, y, label=f'w = {w}')

# Set plot labels and title
plt.xlabel('x')
plt.ylabel('y')
plt.title('Visualization of y = wx^2 for Different w Values')
plt.legend()
# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# Observations: Different $w$ values directly influence the curvature and orientation of the curve. Positive $w$ values yield parabolas that open upwards, while negative $w$ values produce curves that open downwards.

# %% [markdown]
# # **Linear Models**

# %% [markdown]
# Object: now, we will take a step further and introduce the concept of linear resgression. You will try to implement and visualize a simple **Linear Regression Model** using Python.
#
# Linear regression is a fundamental concept in machine learning. It's a method to predict a continuous output variable y based on input features X. The goal is to fit a linear model with coefficients $w = (w_{1}, ..., w_{p})$ to minimize the residual sum of squares between the observed targets in the dataset, and the targets predicted by the linear approximation. Mathematically it solves a problem of the form:
#
# $\min_{w}\left \| Xw-y \right \|_{2}^{2}$

# %%
from sklearn import linear_model

# %%
# Generate example data
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])

# %%
# Reshape data for the model
x = x.reshape(-1, 1)

# %%
# Initialize the Linear Regression model
reg = linear_model.LinearRegression()
# Train the model
reg.fit(x, y)
# Out:
# LinearRegression()

# %%
# The coefficients
print("Coefficients: \n", reg.coef_)
# Out:
# Coefficients:
#  [0.6]

# %%
# Predictions using the model
y_pred = reg.predict(x)

# %%
# Visualize the data and the linear regression line
plt.scatter(x, y, color='blue', label='Original Data')
plt.plot(x, y_pred, color='red', label='Linear Regression Line')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title('Linear Regression Model')
plt.show()

# %% [markdown]
# Observations:
#
#
# *   The linear regression line is the best-fitting line that represents the data.
# *   The coefficient values/parameters indicate the relationship between the variables.

# %% [markdown]
# Assignment: Now, it's your turn! Your assignment is to modify the example data ($x$ and $y$) and observe how it impacts the linear regression line. Experiment with different datasets and see how the model reacts to changes in the input data.
